# %%
# Write a python code to reverse the digits of a number
# input=52 output=25    // acceptance criteria
#Problem No.1:
number = 52
string_number = str(number)
print(type(string_number))
int(string_number[::-1])

while number>0:
    n=number%10
    number=number //10
    print(number)
    print(n)
# Out:
# <class 'str'>
# 25

# %%
number = 52
rev = 0
while number>0:
    n = number%10
    rev = rev*10+n
    number = number//10
print(rev)
# Out:
# 25

# %% [markdown]
# Algorithm:
# Step 1 : Convert the sentence to list using split()
# Step 2 : For loop: for i in list:
#         Step a : IF loop: if len(i)>len(list):
#                             i=list
# Step 3 : print the longest word

# %%
# In python program find the longest word in the sentence
# Problem No.2:
sentence = "The fox jumps over the lazy dog"
word = sentence.split()
longest = ""
for i in word:
    if len(i)>len(longest):
        longest = i
print(longest)
# Out:
# jumps

# %% [markdown]
# Algorithm:
# write the python code to find the 1st non -repeating character in a string
# Step 1: check the index of the word
# Step 2: Compare the character of that index to second character
#         Step A.: Using for loop check the character of that string to another
#         Step B.: Using If loop compare it
#             text[0]=text[1]...true condition
#
#         OR
# Step 1: check the count of each word
# Step 2: compare with each of the letter in the word

# %%
# Program to print non repetive letter in the sentence 
# Problem No.3:
word = "aryan"
for i in word:
    if sentence.count(i)==1:
        print(i)
        break
# Out:
# a

# %%
# Program to print the number is even or odd
# Problem No.4:
number = int(input("Enter the number: "))
if number%2==0:
    print("its even number")
else:
    print("Its odd number")
# Out:
# its even number
